# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulxoliqMirzayev/Machine-Learning/blob/main/Untitled39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import tree
from matplotlib import pyplot as plt
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%203/data/drug200.csv"
df = pd.read_csv(url)

# %%
df.sample(10)
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 4     61   F     LOW        HIGH   18.043  drugY
# 85    59   M    HIGH        HIGH   13.935  drugB
# 145   61   M  NORMAL        HIGH    9.443  drugX
# 40    73   F  NORMAL        HIGH   19.221  drugY
# 174   42   M    HIGH      NORMAL   12.766  drugA
# 128   47   M     LOW      NORMAL   33.542  drugY
# 111   47   F  NORMAL      NORMAL    6.683  drugX
# 121   15   M    HIGH      NORMAL   17.206  drugY
# 56    65   M    HIGH      NORMAL   11.340  drugB
# 90    62   M  NORMAL        HIGH   16.594  drugY

# %%
encoder = LabelEncoder()
df['Sex'] = encoder.fit_transform(df['Sex'].values)
df['BP'] = encoder.fit_transform(df['BP'].values)
df['Cholesterol'] = encoder.fit_transform(df['Cholesterol'].values)
df.sample(10)
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 98    20    1   0            1   35.639  drugY
# 137   35    0   0            0   12.894  drugA
# 147   26    0   0            1   12.307  drugA
# 82    32    0   1            0    9.712  drugC
# 175   73    0   0            0   18.348  drugY
# 120   28    1   2            0   27.064  drugY
# 97    56    0   0            0   25.395  drugY
# 54    68    0   0            1   10.189  drugB
# 194   46    0   0            0   34.686  drugY
# 14    50    0   2            0   12.703  drugX

# %%
X = df[['Age','Sex','BP','Cholesterol','Na_to_K']].values
X[0:5]
# Out:
# array([[23.   ,  0.   ,  0.   ,  0.   , 25.355],
#        [47.   ,  1.   ,  1.   ,  0.   , 13.093],
#        [47.   ,  1.   ,  1.   ,  0.   , 10.114],
#        [28.   ,  0.   ,  2.   ,  0.   ,  7.798],
#        [61.   ,  0.   ,  1.   ,  0.   , 18.043]])

# %%
y = df['Drug'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=20)

# %%
tree_model = DecisionTreeClassifier()
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = tree_model.predict(X_test)

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#        drugA       1.00      1.00      1.00         7
#        drugB       1.00      1.00      1.00         4
#        drugC       0.75      1.00      0.86         9
#        drugX       1.00      0.81      0.89        21
#        drugY       0.97      1.00      0.99        39
#
#     accuracy                           0.95        80
#    macro avg       0.94      0.96      0.95        80
# weighted avg       0.96      0.95      0.95        80

# %%
# print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, y_predict))

# %%
sns.heatmap(confusion_matrix(y_test, y_predict), annot=True)
plt.show()

# %%
predict = cross_val_predict(estimator = tree_model, X = X, y = y, cv = 5)
print("Classification Report: \n",classification_report(y, predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        drugA       0.92      1.00      0.96        23
#        drugB       1.00      0.88      0.93        16
#        drugC       1.00      1.00      1.00        16
#        drugX       1.00      0.98      0.99        54
#        drugY       0.99      1.00      0.99        91
#
#     accuracy                           0.98       200
#    macro avg       0.98      0.97      0.98       200
# weighted avg       0.99      0.98      0.98       200

# %%
cols = df.drop('Drug', axis=1).columns
classes = df['Drug'].unique()

plt.figure(figsize=(30,20))
tree.plot_tree(tree_model, feature_names=cols, class_names=classes,filled=True)
plt.show()

# %%
tree_model = DecisionTreeClassifier(min_impurity_decrease=0.01)
tree_model.fit(X_train, y_train)
y_predict = tree_model.predict(X_test)
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, y_predict))

plt.figure(figsize=(30,20))
tree.plot_tree(tree_model, feature_names=cols, class_names=classes, filled=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-ba9a28d613cc> in <cell line: 4>()
#       2 tree_model.fit(X_train, y_train)
#       3 y_predict = tree_model.predict(X_test)
# ----> 4 print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, y_predict))
#       5
#       6 plt.figure(figsize=(30,20))
#
# NameError: name 'metrics' is not defined

# %%
tree_model = DecisionTreeClassifier(min_impurity_decrease=0.0, max_depth=3)
tree_model.fit(X_train, y_train)
y_predict = tree_model.predict(X_test)
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, y_predict))

plt.figure(figsize=(30,20))
tree.plot_tree(tree_model, feature_names=cols, class_names=classes, filled=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-1254844918cd> in <cell line: 4>()
#       2 tree_model.fit(X_train, y_train)
#       3 y_predict = tree_model.predict(X_test)
# ----> 4 print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, y_predict))
#       5
#       6 plt.figure(figsize=(30,20))
#
# NameError: name 'metrics' is not defined

# %%
rf_model = RandomForestClassifier(n_estimators=20)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        drugA       1.00      1.00      1.00         7
#        drugB       1.00      1.00      1.00         4
#        drugC       1.00      0.89      0.94         9
#        drugX       0.95      0.95      0.95        21
#        drugY       0.97      1.00      0.99        39
#
#     accuracy                           0.97        80
#    macro avg       0.99      0.97      0.98        80
# weighted avg       0.98      0.97      0.97        80

# %%
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-c44814d213a0> in <cell line: 1>()
# ----> 1 print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, y_pred))
#
# NameError: name 'metrics' is not defined
