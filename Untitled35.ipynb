# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulxoliqMirzayev/Machine-Learning/blob/main/Untitled35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn

URL = URL = "https://github.com/ageron/handson-ml2/blob/master/datasets/housing/housing.csv?raw=true"
df = pd.read_csv(URL)

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)

x_train = train_set.drop("median_house_value", axis=1)
y_train = train_set["median_house_value"].copy()

x_num = x_train.drop("ocean_proximity", axis=1)

# %%
from sklearn.base import BaseEstimator, TransformerMixin

rooms_ix, bedrooms_ix, population_ix, households_ix = 3, 4, 5, 6

class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_bedrooms_per_room=True):
        self.add_bedrooms_per_room = add_bedrooms_per_room
    def fit(self, X, y=None):
        return self
    def transform(self, X):
      rooms_per_household = X[:, rooms_ix] / X[:, households_ix]
      population_per_household = X[:, population_ix] / X[:, households_ix]
      if self.add_bedrooms_per_room:
        add_bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
        return np.c_[X, rooms_per_household, population_per_household, add_bedrooms_per_room]
      else:
        return np.c_[X, rooms_per_household, population_per_household]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('attribs_adder', CombinedAttributesAdder()),
    ('std_scaler', StandardScaler()),
])

# %%
from sklearn.compose import ColumnTransformer

num_attribs = list(x_num)
cat_attribs = ["ocean_proximity"]

full_pipeline = ColumnTransformer([
    ("num", num_pipeline, num_attribs),
    ("cat", OneHotEncoder(), cat_attribs),
])

# %%
x_prepared = full_pipeline.fit_transform(x_train)

# %%
from sklearn.linear_model import LinearRegression

LR_model = LinearRegression()
LR_model.fit(x_prepared, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_train.sample(10)

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8440     -118.36     33.91                41.0       2048.0           439.0
# 1037     -120.69     38.44                13.0       1473.0           265.0
# 10181    -117.95     33.86                35.0       2375.0           439.0
# 11977    -117.50     34.00                15.0       1929.0           317.0
# 219      -122.21     37.79                35.0       1745.0           409.0
# 14168    -117.06     32.76                36.0       2785.0           577.0
# 15124    -116.88     32.86                 9.0       3049.0           471.0
# 9928     -122.31     38.30                45.0       3023.0           659.0
# 14889    -117.09     32.61                23.0       1157.0           309.0
# 10260    -117.85     33.89                22.0       4020.0           655.0
#
#        population  households  median_income ocean_proximity
# 8440       1191.0       429.0         3.8000       <1H OCEAN
# ...

# %%
test_labels = y_train.loc[test_data.index]
test_labels
# Out:
# 8440     222500.0
# 1037     121300.0
# 10181    193500.0
# 11977    128500.0
# 219      143800.0
# 14168    156800.0
# 15124    196600.0
# 9928     126000.0
# 14889    118800.0
# 10260    262300.0
# Name: median_house_value, dtype: float64

# %%
test_data_prepared = full_pipeline.transform(test_data)
predicted_labels = LR_model.predict(test_data_prepared)

# %%
predicted_labels
# Out:
# array([238154.33934106, 132149.87571662, 239804.11378485, 146863.49310627,
#        194050.59932959, 177680.14947911, 226222.42876187, 229167.68667911,
#        169533.32418887, 300642.8277296 ])

# %%
pd.DataFrame({'Predicted': predicted_labels, 'Actual': test_labels})
# Out:
#            Predicted    Actual
# 8440   238154.339341  222500.0
# 1037   132149.875717  121300.0
# 10181  239804.113785  193500.0
# 11977  146863.493106  128500.0
# 219    194050.599330  143800.0
# 14168  177680.149479  156800.0
# 15124  226222.428762  196600.0
# 9928   229167.686679  126000.0
# 14889  169533.324189  118800.0
# 10260  300642.827730  262300.0

# %%
# import pandas as pd
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
# from sklearn.pipeline import Pipeline
# from sklearn.impute import SimpleImputer
# from sklearn.preprocessing import StandardScaler, OneHotEncoder
# from sklearn.compose import ColumnTransformer

# # 1. CSV formatida ma'lumotlarni yuklash
# URL = "https://github.com/ageron/handson-ml2/blob/master/datasets/housing/housing.csv?raw=true"
# df = pd.read_csv(URL)

# # 2. Maqsadli ustunni ajratib olish
# housing = df.drop("median_house_value", axis=1)
# housing_labels = df["median_house_value"].copy()

# # 3. Raqamli va kategoriyali ustunlarni aniqlash
# num_attribs = list(housing.select_dtypes(include=[np.number]).columns)
# cat_attribs = list(housing.select_dtypes(exclude=[np.number]).columns)

# # 4. Raqamli ustunlar uchun Pipeline
# num_pipeline = Pipeline([
#     ('imputer', SimpleImputer(strategy="median")),
#     ('scaler', StandardScaler())
# ])

# # 5. Kategoriyali ustunlar uchun Pipeline
# cat_pipeline = Pipeline([
#     ('imputer', SimpleImputer(strategy="most_frequent")),
#     ('onehot', OneHotEncoder())
# ])

# # 6. Barcha ustunlarni birlashtiradigan ColumnTransformer
# full_pipeline = ColumnTransformer([
#     ('num', num_pipeline, num_attribs),
#     ('cat', cat_pipeline, cat_attribs)
# ])

# # 7. Ma'lumotlarni tozalash va tayyorlash
# housing_prepared = full_pipeline.fit_transform(housing)

# # 8. Linear Regression modelini yaratish va o'qitish
# LR_model = LinearRegression()
# LR_model.fit(housing_prepared, housing_labels)

# # 9. Test ma'lumotlaridan tasodifiy 10 ta namunani tanlash
# test_data = df.sample(10)
# test_labels = test_data["median_house_value"].copy()

# # 10. Test ma'lumotlarini tayyorlash
# test_data_prepared = full_pipeline.transform(test_data.drop("median_house_value", axis=1))

# # 11. Bashorat qilish
# predicted_labels = LR_model.predict(test_data_prepared)

# # 12. Bashorat qilingan qiymatlarni va haqiqiy qiymatlarni DataFrame'da ko'rish
# result_df = pd.DataFrame({'Predicted': predicted_labels, 'Actual': test_labels})
# print(result_df)

# %%
# import pandas as pd
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.base import BaseEstimator, TransformerMixin
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import StandardScaler, OneHotEncoder
# from sklearn.compose import ColumnTransformer
# from sklearn.linear_model import LinearRegression
# from sklearn.impute import SimpleImputer

# # 1. CSV formatida ma'lumotlarni yuklash
# URL = "https://github.com/ageron/handson-ml2/blob/master/datasets/housing/housing.csv?raw=true"
# df = pd.read_csv(URL)

# # 2. Maqsadli ustunni ajratib olish va train/test ma'lumotlarini ajratish
# train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)
# x_train = train_set.drop("median_house_value", axis=1)
# y_train = train_set["median_house_value"].copy()

# # 3. Kategoriyali ustunni ajratish
# x_num = x_train.drop("ocean_proximity", axis=1)
# num_attribs = list(x_num.columns)
# cat_attribs = ["ocean_proximity"]

# # 4. Maxsus transformer yaratish
# rooms_ix, bedrooms_ix, population_ix, households_ix = 3, 4, 5, 6

# class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
#     def __init__(self, add_bedrooms_per_room=True):
#         self.add_bedrooms_per_room = add_bedrooms_per_room
#     def fit(self, X, y=None):
#         return self
#     def transform(self, X):
#         rooms_per_household = X[:, rooms_ix] / X[:, households_ix]
#         population_per_household = X[:, population_ix] / X[:, households_ix]
#         if self.add_bedrooms_per_room:
#             bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
#             return np.c_[X, rooms_per_household, population_per_household, bedrooms_per_room]
#         else:
#             return np.c_[X, rooms_per_household, population_per_household]

# # 5. Raqamli ustunlar uchun pipeline
# num_pipeline = Pipeline([
#     ('imputer', SimpleImputer(strategy="median")),
#     ('attribs_adder', CombinedAttributesAdder()),
#     ('std_scaler', StandardScaler()),
# ])

# # 6. Barcha ustunlarni birlashtirish uchun ColumnTransformer
# full_pipeline = ColumnTransformer([
#     ("num", num_pipeline, num_attribs),
#     ("cat", OneHotEncoder(), cat_attribs),
# ])

# # 7. Ma'lumotlarni tozalash va tayyorlash
# x_prepared = full_pipeline.fit_transform(x_train)

# # 8. Linear Regression modelini yaratish va o'qitish
# LR_model = LinearRegression()
# LR_model.fit(x_prepared, y_train)

# # 9. Test ma'lumotlaridan tasodifiy 10 ta namunani tanlash
# test_data = x_train.sample(10)
# test_labels = y_train.loc[test_data.index]

# # 10. Test ma'lumotlarini tayyorlash
# test_data_prepared = full_pipeline.transform(test_data)

# # 11. Bashorat qilish
# predicted_labels = LR_model.predict(test_data_prepared)

# # 12. Bashorat qilingan qiymatlarni va haqiqiy qiymatlarni ko'rish
# result_df = pd.DataFrame({'Predicted': predicted_labels, 'Actual': test_labels})
# print(result_df)

# %%
# import pandas as pd
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.metrics import mean_squared_error
# from sklearn.base import BaseEstimator, TransformerMixin
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import StandardScaler, OneHotEncoder
# from sklearn.compose import ColumnTransformer
# from sklearn.impute import SimpleImputer

# # 1. CSV formatida ma'lumotlarni yuklash
# URL = "https://github.com/ageron/handson-ml2/blob/master/datasets/housing/housing.csv?raw=true"
# df = pd.read_csv(URL)

# # 2. Maqsadli ustunni ajratib olish va train/test ma'lumotlarini ajratish
# train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)
# x_train = train_set.drop("median_house_value", axis=1)
# y_train = train_set["median_house_value"].copy()
# x_test = test_set.drop("median_house_value", axis=1)
# y_test = test_set["median_house_value"].copy()

# # 3. Kategoriyali ustunni ajratish
# x_num = x_train.drop("ocean_proximity", axis=1)
# num_attribs = list(x_num.columns)
# cat_attribs = ["ocean_proximity"]

# # 4. Maxsus transformer yaratish
# rooms_ix, bedrooms_ix, population_ix, households_ix = 3, 4, 5, 6

# class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
#     def __init__(self, add_bedrooms_per_room=True):
#         self.add_bedrooms_per_room = add_bedrooms_per_room
#     def fit(self, X, y=None):
#         return self
#     def transform(self, X):
#         rooms_per_household = X[:, rooms_ix] / X[:, households_ix]
#         population_per_household = X[:, population_ix] / X[:, households_ix]
#         if self.add_bedrooms_per_room:
#             bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
#             return np.c_[X, rooms_per_household, population_per_household, bedrooms_per_room]
#         else:
#             return np.c_[X, rooms_per_household, population_per_household]

# # 5. Raqamli ustunlar uchun pipeline
# num_pipeline = Pipeline([
#     ('imputer', SimpleImputer(strategy="median")),
#     ('attribs_adder', CombinedAttributesAdder()),
#     ('std_scaler', StandardScaler()),
# ])

# # 6. Barcha ustunlarni birlashtirish uchun ColumnTransformer
# full_pipeline = ColumnTransformer([
#     ("num", num_pipeline, num_attribs),
#     ("cat", OneHotEncoder(), cat_attribs),
# ])

# # 7. Ma'lumotlarni tozalash va tayyorlash
# x_train_prepared = full_pipeline.fit_transform(x_train)
# x_test_prepared = full_pipeline.transform(x_test)

# # 8. Random Forest modelini yaratish va o'qitish
# rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
# rf_model.fit(x_train_prepared, y_train)

# # 9. Bashorat qilish va aniqlikni tekshirish
# y_train_pred = rf_model.predict(x_train_prepared)
# y_test_pred = rf_model.predict(x_test_prepared)

# # 10. O'rtacha kvadrat xatolikni (RMSE) hisoblash
# train_mse = mean_squared_error(y_train, y_train_pred)
# test_mse = mean_squared_error(y_test, y_test_pred)
# train_rmse = np.sqrt(train_mse)
# test_rmse = np.sqrt(test_mse)

# print(f"Train RMSE: {train_rmse}")
# print(f"Test RMSE: {test_rmse}")

# # 11. Test ma'lumotlaridan tasodifiy 10 ta namunani tanlash va bashorat qilish
# test_data = x_test.sample(10, random_state=42)
# test_labels = y_test.loc[test_data.index]
# test_data_prepared = full_pipeline.transform(test_data)
# predicted_labels = rf_model.predict(test_data_prepared)

# # 12. Bashorat qilingan va haqiqiy qiymatlarni ko'rish
# result_df = pd.DataFrame({'Predicted': predicted_labels, 'Actual': test_labels})
# print(result_df)

# %%
pd.DataFrame({'Predicted': predicted_labels, 'Actual': test_labels})
# Out:
#            Predicted    Actual
# 8440   238154.339341  222500.0
# 1037   132149.875717  121300.0
# 10181  239804.113785  193500.0
# 11977  146863.493106  128500.0
# 219    194050.599330  143800.0
# 14168  177680.149479  156800.0
# 15124  226222.428762  196600.0
# 9928   229167.686679  126000.0
# 14889  169533.324189  118800.0
# 10260  300642.827730  262300.0

# %%
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20046    -119.01     36.06                25.0       1505.0             NaN
# 3024     -119.46     35.14                30.0       2943.0             NaN
# 15663    -122.44     37.80                52.0       3830.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
# 9814     -121.93     36.62                34.0       2351.0             NaN
# ...          ...       ...                 ...          ...             ...
# 15362    -117.22     33.36                16.0       3165.0           482.0
# 16623    -120.83     35.36                28.0       4323.0           886.0
# 18086    -122.05     37.31                25.0       4111.0           538.0
# 2144     -119.76     36.77                36.0       2507.0           466.0
# 3665     -118.37     34.22                17.0       1787.0           463.0
#
# ...

# %%
x_test = test_set.drop("median_house_value", axis=1)
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20046    -119.01     36.06                25.0       1505.0             NaN
# 3024     -119.46     35.14                30.0       2943.0             NaN
# 15663    -122.44     37.80                52.0       3830.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
# 9814     -121.93     36.62                34.0       2351.0             NaN
# ...          ...       ...                 ...          ...             ...
# 15362    -117.22     33.36                16.0       3165.0           482.0
# 16623    -120.83     35.36                28.0       4323.0           886.0
# 18086    -122.05     37.31                25.0       4111.0           538.0
# 2144     -119.76     36.77                36.0       2507.0           466.0
# 3665     -118.37     34.22                17.0       1787.0           463.0
#
# ...

# %%
y_test = test_set["median_house_value"].copy()
y_test
# Out:
# 20046     47700.0
# 3024      45800.0
# 15663    500001.0
# 20484    218600.0
# 9814     278000.0
#            ...
# 15362    263300.0
# 16623    266800.0
# 18086    500001.0
# 2144      72300.0
# 3665     151500.0
# Name: median_house_value, Length: 4128, dtype: float64

# %%
x_test_prepared = full_pipeline.transform(x_test)

# %%
y_prepared = LR_model.predict(x_test_prepared)

# %%
y_prepared
# Out:
# array([ 61874.25460143, 121853.52511139, 267770.94368091, ...,
#        447837.04647878, 117275.9214608 , 185597.46125194])

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_prepared)
print("RMSE=", np.sqrt(mse))
# Out:
# RMSE= 72701.32600762135

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(x_prepared, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_prepared = rf_model.predict(x_test_prepared)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_prepared)
print("RMSE=", np.sqrt(mse))
# Out:
# RMSE= 50326.390427984144

# %%
x = df.drop("median_house_value", axis=1)
y = df["median_house_value"].copy()

x_prepared = full_pipeline.transform(x)

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(LR_model, x_prepared, y, scoring="neg_mean_squared_error", cv=10)
rmse_scores = np.sqrt(-scores)
rmse_scores
# Out:
# array([84188.51219065, 61197.24357613, 86752.24346334, 62289.14292385,
#        80540.40041898, 68919.39949642, 52503.82940087, 90910.07884989,
#        77674.67507925, 53941.60539478])

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(rmse_scores)
# Out:
# Scores: [84188.51219065 61197.24357613 86752.24346334 62289.14292385
#  80540.40041898 68919.39949642 52503.82940087 90910.07884989
#  77674.67507925 53941.60539478]
# Mean: 71891.71307941683
# Standard deviation: 13249.525989444986

# %%
scores = cross_val_score(rf_model, x_prepared, y, scoring="neg_mean_squared_error", cv=10)
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)
# Out:
# Scores: [94890.89506621 47545.22300181 65003.39338764 57000.45356587
#  60922.02845781 60087.46147697 46790.46292942 79286.40187999
#  74355.09071765 49337.61988477]
# Mean: 63521.90303681473
# Standard deviation: 14661.375021144244

# %%
import pickle

with open("model.pkl", "wb") as file:
    pickle.dump(rf_model, file)

# %%
with open("model.pkl", "rb") as file:
    model = pickle.load(file)

# %%
import joblib

joblib.dump(LR_model, "LR_model.pkl")
# Out:
# ['LR_model.pkl']

# %%
model = joblib.load("LR_model.pkl")

# %%
scores = cross_val_score(model, x_prepared, y, scoring="neg_mean_squared_error", cv=10)
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)
# Out:
# Scores: [84188.51219065 61197.24357613 86752.24346334 62289.14292385
#  80540.40041898 68919.39949642 52503.82940087 90910.07884989
#  77674.67507925 53941.60539478]
# Mean: 71891.71307941683
# Standard deviation: 13249.525989444986
